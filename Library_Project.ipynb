# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaveesha-2001/Python-Library-System/blob/main/Library_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Statements**

# %%
import csv

# %% [markdown]
# Global **Variables**

# %%
current_ID = 1

new_additions = []

filename = "library.csv"

fields = ['ID', 'Title', 'Author', 'Genre', 'Year', 'Location']

data = []

# %% [markdown]
# **CSV File**

# %%
#!touch $filename

# %%
with open(filename, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(dict(row))
if len(data) > 0:
    current_ID = data[:-1][0].get("ID")
    current_ID = int(current_ID) + 1

# %% [markdown]
# **Function to add a record**

# %%
def addRecord():
  global current_ID
  new_record = {
      "ID": str(current_ID),
      "Title": input("What is the title of the book? >"),
      "Author": input("What is the author's first name?  >"),
      "Genre": input("What genre is the book?  >"),
      "Year": input("What year was the book released?  >"),
      "Location": input("Where is the book? > ")
  }
  new_additions.append(new_record)
  current_ID = current_ID + 1
  print("-"*15)
  print("New Record added successfully!")

# %% [markdown]
# **Function to display the data**

# %%
def displayData():
  for item in fields:
      print("%-25s"%item, end='')
  print("\n")
  for row in data:
      for key, val in row.items():
          print("%-25s"%val, end='')
      print("\n")
  for row in new_additions:
      for key, val in row.items():
          print("%-25s"%val, end='')
      print("\n")

# %% [markdown]
# **Function to Search and display data**

# %%
def searchData() :
  #Search the data
  search_term = input("What would you like to search for?").lower()
  results = []
  for row in data:
      for key, val in row.items():
          if search_term in val.lower():
              results.append(row)
  for item in new_additions:
      for key, val in item.items():
          if search_term in val.lower():
              results.append(item)
  #Display the results
  if len(results) > 0:
      for item in fields:
          print("%-25s"%item, end='')
      print("\n")
      for item in results:
          for key, val in item.items():
              print("%-25s"%val, end='')
          print("\n")
  else:
      print("Sorry no records found")

# %% [markdown]
# **Execute the code**

# %%
print("------Welcome to the Python Library organiser------")

choice = ""

while choice.lower() != "x":
    print("""What would you like to do?
    1 - Add a book
    2 - Display your Books
    3 - Search for a Book""")

    choice = input(">")

    if choice == "1":
        #Code to add a record
        addRecord()

    elif choice == "2":
        #Display the data
        displayData()

    elif choice == "3":
        #Search the data
        searchData()


    elif choice.lower() == "x":
        print("Thank you! Shutting down.")
    else:
        print("Sorry, I didnt recognise that option")
# Out:
# ------Welcome to the Python Library organiser------
# What would you like to do?
#     1 - Add a book
#     2 - Display your Books
#     3 - Search for a Book
# >1
# What is the title of the book? >Madol Duwa
# What is the author's first name?  >Martin Wickramasinghe
# What genre is the book?  >Navel
# What year was the book released?  >1974
# Where is the book? > Shelf A
# ---------------
# New Record added successfully!
# What would you like to do?
#     1 - Add a book
#     2 - Display your Books
#     3 - Search for a Book
# >1
# What is the title of the book? >Sepalika
# What is the author's first name?  >Saman Kumara
# What genre is the book?  >Navel
# What year was the book released?  >2001
# Where is the book? > Shelf B
# ---------------
# New Record added successfully!
# What would you like to do?
#     1 - Add a book
#     2 - Display your Books
#     3 - Search for a Book
# >2
# ID                       Title                    Author                   Genre                    Year                     Location
#
# 1                        Madol Duwa               Martin Wickramasinghe    Navel                    1974                     Shelf A
#
# 2                        Sepalika                 Saman Kumara             Navel                    2001                     Shelf B
#
# What would you like to do?
#     1 - Add a book
#     2 - Display your Books
#     3 - Search for a Book
# >3
# What would you like to search for?Sepalika
# ID                       Title                    Author                   Genre                    Year                     Location
#
# 2                        Sepalika                 Saman Kumara             Navel                    2001                     Shelf B
#
# What would you like to do?
#     1 - Add a book
#     2 - Display your Books
#     3 - Search for a Book
# >x
# Thank you! Shutting down.

# %% [markdown]
# **Save the newly added record in the CSV**

# %%
if len(new_additions) > 0:
    with open(filename, 'a') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fields)
        writer.writeheader()
        for item in new_additions:
            writer.writerow(item)
